# %%
import os
import json
import time

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset


MAX_POEM_LENGTH = 150

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
use_pin_memory = torch.cuda.is_available()  # Only use pin_memory if GPU exists
print(f"Cuda available: {torch.cuda.is_available()}")
# Out:
# Cuda available: True

# %%
# Read poems from json file
def parse_data(data_path):
    poems = []

    with open(data_path, "r", encoding="utf-8") as f:
        poems_data = json.load(f)

    for poem in poems_data:
        poem_text = "《" + poem["title"] + "》\n" + "\n".join(poem["paragraphs"])
        if len(poem_text) > MAX_POEM_LENGTH:
            poem_text = poem_text[:MAX_POEM_LENGTH]
        poems.append(poem_text)

    return poems

if os.path.exists("data/poem_tang.json"):
    poems = parse_data("data/poem_tang.json")
else:
    # !wget -P data https://raw.githubusercontent.com/Trilobit-coder/NanoPoet/main/data/poem_tang.json
    poems = parse_data("data/poem_tang.json")
print(f"Total poems:{len(poems)}")
print(poems[0:10])
# Out:
# Total poems:43103
# ['《帝京篇十首》\n秦川雄帝宅，函谷壯皇居。綺殿千尋起，離宮百雉餘。\n連薨遙接漢，飛觀迥淩虛。雲日隱層闕，風煙出綺疏。\n岩廊罷機務，崇文聊駐輦。玉匣啟龍圖，金繩披鳳篆。\n韋編斷仍續，縹帙舒還卷。對此乃淹留，欹案觀墳典。\n移步出詞林，停輿欣武宴。雕弓寫明月，駿馬疑流電。\n驚雁落虛弦，啼猿悲急箭。閱賞誠多美', '《飲馬長城窟行》\n塞外悲風切，交河冰已結。瀚海百重波，陰山千里雪。\n迥戍危烽火，層巒引高節。悠悠卷旆旌，飲馬出長城。\n寒沙連騎跡，朔吹斷邊聲。胡塵清玉塞，羌笛韻金鉦。\n絕漠干戈戢，車徒振原隰。都尉反龍堆，將軍旋馬邑。\n揚麾氛霧靜，紀石功名立。荒裔一戎衣，靈台凱歌入。', '《執契靜三邊》\n執契靜三邊，持衡臨萬姓。玉彩輝關燭，金華流日鏡。\n無為宇宙清，有美璿璣正。皎佩星連景，飄衣雲結慶。\n戢武耀七德，升文輝九功。煙波澄舊碧，塵火息前紅。\n霜野韜蓮劍，關城罷月弓。錢綴榆天合，新城柳塞空。\n花銷蔥嶺雪，縠盡流沙霧。秋駕轉兢懷，春冰彌軫慮。\n書絕龍庭羽，烽休鳳穴戍。衣宵寢二難', '《正日臨朝》\n條風開獻節，灰律動初陽。百蠻奉遐贐，萬國朝未央。\n雖無舜禹跡，幸欣天地康。車軌同八表，書文混四方。\n赫奕儼冠蓋，紛綸盛服章。羽旄飛馳道，鐘鼓震岩廊。\n組練輝霞色，霜戟耀朝光。晨宵懷至理，終愧撫遐荒。', '《幸武功慶善宮》\n壽丘惟舊跡，酆邑乃前基。粵予承累聖，懸弧亦在茲。\n弱齡逢運改，提劍郁匡時。指麾八荒定，懷柔萬國夷。\n梯山咸入款，駕海亦來思。單于陪武帳，日逐衛文䪥。\n端扆朝四岳，無為任百司。霜節明秋景，輕冰結水湄。\n芸黃遍原隰，禾穎積京畿。共樂還鄉宴，歡比大風詩。', '《重幸武功》\n代馬依朔吹，驚禽愁昔叢。況茲承眷德，懷舊感深衷。\n積善忻餘慶，暢武悅成功。垂衣天下治，端拱車書同。\n白水巡前跡，丹陵幸舊宮。列筵歡故老，高宴聚新豐。\n駐蹕撫田畯，回輿訪牧童。瑞氣縈丹闕，祥煙散碧空。\n孤嶼含霜白，遙山帶日紅。於焉歡擊築，聊以詠南風。', '《經破薛舉戰地》\n昔年懷壯氣，提戈初仗節。心隨朗日高，志與秋霜潔。\n移鋒驚電起，轉戰長河決。營碎落星沉，陣卷橫雲裂。\n一揮氛沴靜，再舉鯨鯢滅。于茲俯舊原，屬目駐華軒。\n沉沙無故跡，減灶有殘痕。浪霞穿水淨，峰霧抱蓮昏。\n世途亟流易，人事殊今昔。長想眺前蹤，撫躬聊自適。', '《過舊宅二首》\n新豐停翠輦，譙邑駐鳴笳。園荒一徑斷，苔古半階斜。\n前池消舊水，昔樹發今花。一朝辭此地，四海遂為家。\n金輿巡白水，玉輦駐新豐。紐落藤披架，花殘菊破叢。\n葉鋪荒草蔓，流竭半池空。紉佩蘭凋徑，舒圭葉翦桐。\n昔地一蕃內，今宅九圍中。架海波澄鏡，韜戈器反農。\n八表文同軌，無勞歌大風。', '《還陝述懷》\n慨然撫長劍，濟世豈邀名。星旗紛電舉，日羽肅天行。\n遍野屯萬騎，臨原駐五營。登山麾武節，背水縱神兵。\n在昔戎戈動，今來宇宙平。', '《入潼關》\n崤函稱地險，襟帶壯兩京。霜峰直臨道，冰河曲繞城。\n古木參差影，寒猿斷續聲。冠蓋往來合，風塵朝夕驚。\n高談先馬度，偽曉預雞鳴。棄繻懷遠志，封泥負壯情。\n別有真人氣，安知名不名。']

# %%
# Split up the data into train and eval
use_index = int(1.0 * len(poems))
poems = poems[:use_index]
split_index = int(0.9 * len(poems))  # first 90% will be train, rest eval
train_poems = poems[:split_index]
eval_poems = poems[split_index:]
print(f"Used poems:{len(poems)}")
print(f"Train poems: {len(train_poems)}")
print(f"Eval poems: {len(eval_poems)}")
# Out:
# Used poems:43103
# Train poems: 38792
# Eval poems: 4311

# %%
# Encode all poems
# here are all the unique characters that occur in this text
text = "".join(poems)
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(f"vocab_size: {vocab_size}")

stoi = {ch: i for i, ch in enumerate(chars)}
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string
train_encoded = [
    torch.tensor(encode(poem), dtype=torch.long) for poem in train_poems
]
train_data = pad_sequence(train_encoded, batch_first=True, padding_value=0)
train_attention_mask = (train_data != 0).long()
eval_encoded = [
    torch.tensor(encode(poem), dtype=torch.long) for poem in eval_poems
]
eval_data = pad_sequence(eval_encoded, batch_first=True, padding_value=0)
eval_attention_mask = (eval_data != 0).long()
# Out:
# vocab_size: 7045

# %%
class PoemDataset(Dataset):
    def __init__(self, data, attention_mask):
        self.input_ids = data
        self.attention_mask = attention_mask
        self.labels = data.clone()
        self.labels[data == 0] = -100

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx],
        }


# Create datasets
train_dataset = PoemDataset(train_data, train_attention_mask)
eval_dataset = PoemDataset(eval_data, eval_attention_mask)
train_loader = DataLoader(
    train_dataset, batch_size=128, shuffle=True, num_workers=2, pin_memory=use_pin_memory
)
eval_loader = DataLoader(
    eval_dataset, batch_size=128, shuffle=False, num_workers=2, pin_memory=use_pin_memory
)

# %%
class PoemTransformer(nn.Module):
    def __init__(self, vocab_size, n_positions, d_model, nhead, num_layers):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoding = nn.Parameter(torch.randn(1, n_positions, d_model) * 0.01)
        self.dropout = nn.Dropout(0.1)

        self.register_buffer(
            "causal_mask",
            torch.triu(torch.ones(n_positions, n_positions) * float('-inf'), diagonal=1)
        )

        encoder_layer = nn.TransformerEncoderLayer(
            d_model,
            nhead,
            dim_feedforward=d_model * 4,
            dropout=0.1,
            activation="gelu",
            batch_first=True,
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers)
        self.lm_head = nn.Linear(d_model, vocab_size)

    def forward(self, input_ids, attention_mask=None, labels=None):
        x = self.embedding(input_ids) + self.pos_encoding[:, : input_ids.size(1), :]
        x = self.dropout(x)

        src_key_padding_mask = None
        if attention_mask is not None:
            src_key_padding_mask = torch.zeros_like(attention_mask, dtype=x.dtype)
            src_key_padding_mask = src_key_padding_mask.masked_fill(attention_mask == 0, float('-inf'))

        sz = input_ids.size(1)
        causal_mask = self.causal_mask[:sz, :sz]

        x = self.transformer(
            x,
            mask=causal_mask,  # Causal mask (prevents looking forward)
            src_key_padding_mask=src_key_padding_mask  # Padding mask (ignores padding)
        )

        logits = self.lm_head(x)

        loss = None
        if labels is not None:
            shift_logits = logits[..., :-1, :].contiguous()
            shift_labels = labels[..., 1:].contiguous()
            loss = F.cross_entropy(
                shift_logits.view(-1, shift_logits.size(-1)),
                shift_labels.view(-1),
                ignore_index=-100,
            )

        return (loss, logits) if loss is not None else logits

# %%
model = PoemTransformer(
    vocab_size=vocab_size,
    n_positions=len(train_data[0]),
    d_model=384,
    nhead=8,
    num_layers=6,
).to(device)
optimizer = optim.AdamW(
    model.parameters(),
    lr=5e-4,
    betas=(0.9, 0.95),
    eps=5e-8,
    weight_decay=0.1
)

# %%
def train(model, train_loader, eval_loader, optimizer, device, epochs=3):
    for epoch in range(epochs):
        print(f"\n{'='*50}")
        print(f"Epoch {epoch+1}/{epochs}")
        print(f"{'='*50}")

        # Training
        model.train()
        total_loss = 0
        epoch_start = time.time()
        batch_times = []

        for batch_idx, batch in enumerate(train_loader):
            batch_start = time.time()

            input_ids = batch["input_ids"].to(device, non_blocking=True)
            attention_mask = batch["attention_mask"].to(device, non_blocking=True)
            labels = batch["labels"].to(device, non_blocking=True)

            optimizer.zero_grad()
            loss, _ = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            batch_times.append(time.time() - batch_start)

            if batch_idx % 50 == 0:
                avg_loss = total_loss / (batch_idx + 1)
                avg_batch_time = (
                    sum(batch_times[-200:]) / len(batch_times[-200:])
                    if batch_times
                    else 0
                )
                remaining_batches = len(train_loader) - batch_idx
                est_time = remaining_batches * avg_batch_time

                print(
                    f"Batch {batch_idx}/{len(train_loader)} | "
                    f"Loss: {loss.item():.4f} | "
                    f"Avg Loss: {avg_loss:.4f} | "
                    f"Speed: {1/avg_batch_time:.1f} batches/s | "
                    f"ETA: {est_time/60:.1f}min"
                )

        epoch_time = time.time() - epoch_start
        avg_train_loss = total_loss / len(train_loader)

        model.eval()
        eval_loss = 0
        with torch.no_grad():
            for batch in eval_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels = batch["labels"].to(device)

                loss, _ = model(input_ids, attention_mask=attention_mask, labels=labels)
                eval_loss += loss.item()

        avg_eval_loss = eval_loss / len(eval_loader)

        print(f"\nEpoch {epoch+1} completed in {epoch_time/60:.2f}min")
        print(f"Train Loss: {avg_train_loss:.4f}")
        print(f"Eval Loss: {avg_eval_loss:.4f}")

        torch.save(
            {
                "epoch": epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "train_loss": avg_train_loss,
                "eval_loss": avg_eval_loss,
            },
            f"poem_epoch_{epoch+1}.pt",
        )

# %%
def generate(model, prompt, max_new_tokens=120, temperature=0.7):
    model.eval()
    tokens = encode(prompt)
    input_ids = torch.tensor([tokens]).to(device)

    with torch.no_grad():
        for _ in range(max_new_tokens):
            outputs = model(input_ids)
            logits = outputs[0] if isinstance(outputs, tuple) else outputs
            logits = logits[:, -1, :] / temperature

            probs = F.softmax(logits, dim=-1)
            next_token = torch.multinomial(probs, num_samples=1)
            input_ids = torch.cat([input_ids, next_token], dim=-1)

    return decode(input_ids[0].tolist())

# %%
def save_model(model, model_path, dimensions_path):
    """Simple function to save model weights and dimensions"""
    torch.save(model.state_dict(), model_path)

    with open(dimensions_path, "w") as f:
        json.dump(
            {
                "vocab_size": model.embedding.num_embeddings,
                "n_positions": model.pos_encoding.size(1),
                "d_model": model.embedding.embedding_dim,
                "nhead": model.transformer.layers[0].self_attn.num_heads,
                "num_layers": len(model.transformer.layers),
            },
            f,
        )

    print(f"Model saved to {model_path}")
    print(f"Dimensions saved to {dimensions_path}")

# %%
def load_model(model_class, model_path, dimensions_path):
    """Simple function to load model weights and dimensions"""
    with open(dimensions_path, "r") as f:
        dimensions = json.load(f)

    model = model_class(
        vocab_size=dimensions["vocab_size"],
        n_positions=dimensions["n_positions"],
        d_model=dimensions["d_model"],
        nhead=dimensions["nhead"],
        num_layers=dimensions["num_layers"],
    )

    model.load_state_dict(torch.load(model_path, weights_only=True))
    model.to(device)
    model.eval()

    print(f"Model loaded from {model_path}")
    return model

# %%
from google.colab import files
if not os.path.exists("NanoPoet_model.pt"):
    model = load_model(
        PoemTransformer, "NanoPoet_model.pt", "NanoPoet_dimensions.json"
    )
else:
    print("--- Starting Training ---")
    train(model, train_loader, eval_loader, optimizer, device, epochs=20)
    save_model(model, "NanoPoet_model.pt", "NanoPoet_dimensions.json")
    files.download("NanoPoet_model.pt")
    files.download("NanoPoet_dimensions.json")

prompt = """《靜夜》"""
generated = generate(model, prompt)
print(f"\nGenerated:\n{generated}\n")
# Out:
# --- Starting Training ---
#
# ==================================================
# Epoch 1/20
# ==================================================
# Batch 0/304 | Loss: 9.0258 | Avg Loss: 9.0258 | Speed: 1.4 batches/s | ETA: 3.5min
# Batch 50/304 | Loss: 6.5532 | Avg Loss: 6.8662 | Speed: 1.4 batches/s | ETA: 3.0min
# Batch 100/304 | Loss: 6.3855 | Avg Loss: 6.6754 | Speed: 1.5 batches/s | ETA: 2.3min
# Batch 150/304 | Loss: 6.2216 | Avg Loss: 6.5423 | Speed: 1.5 batches/s | ETA: 1.7min
# Batch 200/304 | Loss: 5.9843 | Avg Loss: 6.4241 | Speed: 1.5 batches/s | ETA: 1.2min
# Batch 250/304 | Loss: 5.9778 | Avg Loss: 6.3192 | Speed: 1.5 batches/s | ETA: 0.6min
# Batch 300/304 | Loss: 5.7421 | Avg Loss: 6.2268 | Speed: 1.5 batches/s | ETA: 0.0min
#
# Epoch 1 completed in 3.41min
# Train Loss: 6.2211
# Eval Loss: 5.7924
#
# ==================================================
# Epoch 2/20
# ==================================================
# Batch 0/304 | Loss: 5.6487 | Avg Loss: 5.6487 | Speed: 1.5 batches/s | ETA: 3.4min
# Batch 50/304 | Loss: 5.6106 | Avg Loss: 5.6262 | Speed: 1.5 batches/s | ETA: 2.9min
# Batch 100/304 | Loss: 5.5054 | Avg Loss: 5.5756 | Speed: 1.5 batches/s | ETA: 2.3min
# Batch 150/304 | Loss: 5.5201 | Avg Loss: 5.5356 | Speed: 1.5 batches/s | ETA: 1.7min
